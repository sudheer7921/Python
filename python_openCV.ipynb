# %%
import numpy as np
import os,cv2
from PIL import Image

# %%
PATH = 'C:/Users/v/Pictures'
# Define data path
#data_path = PATH + 'Pictures'
#print(data_path)
print(PATH)

img  = cv2.imread('cat.jpg');

#img = img.astype(int)
#img[:,:,1] = img[:,:,1] *2 #tint
img = np.minimum(255,img).astype(np.uin8)

cv2.imshow('cat',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# C:/Users/v/Pictures
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-1dd360c0577a> in <module>()
#       9 #img = img.astype(int)
#      10 #img[:,:,1] = img[:,:,1] *2 #tint
# ---> 11 img = np.minimum(255,img).astype(np.uin8)
#      12
#      13 cv2.imshow('cat',img)
#
# TypeError: unorderable types: int() <= NoneType()
